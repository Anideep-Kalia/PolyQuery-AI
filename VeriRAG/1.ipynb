# %%
# !pip install python-dotenv langchain langchain-core langchain-community langchain-google-genai chromadb langchain-text-splitters beautifulsoup4 sentence-transformers einops langchainhub langsmith faiss-cpu pydantic rank_bm25 sentence-transformers 
# !pip install langchain-google-vertexai python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: langchain in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.2.15)
# Requirement already satisfied: langchain-core in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.2.27)
# Requirement already satisfied: langchain-community in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (0.4.1)
# Requirement already satisfied: langchain-google-genai in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (4.2.1)
# Requirement already satisfied: chromadb in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.5.6)
# Requirement already satisfied: langchain-text-splitters in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (4.14.3)
# Requirement already satisfied: sentence-transformers in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (5.3.0)
# Requirement already satisfied: einops in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (0.8.2)
# Requirement already satisfied: langchainhub in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (0.1.21)
# Requirement already satisfied: langsmith in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (0.7.26)
# Requirement already satisfied: faiss-cpu in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.13.2)
# Requirement already satisfied: pydantic in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (2.12.5)
# Requirement already satisfied: rank_bm25 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (0.2.2)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain) (1.1.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (2.33.1)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: anyio in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith) (4.13.0)
# Requirement already satisfied: certifi in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.12)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from requests>=2.0.0->langsmith) (2.6.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-genai) (1.70.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.49.1)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.6)
# Requirement already satisfied: build>=1.0.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.44.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sentence-transformers) (5.5.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sentence-transformers) (1.9.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: regex>=2025.10.22 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.3)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchainhub) (2.33.0.20260402)
# Requirement already satisfied: pyproject_hooks in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: sympy in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: setuptools<82 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain-google-vertexai in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (3.2.2)
# Requirement already satisfied: python-dotenv in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: bottleneck<2.0.0,>=1.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (1.6.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.97.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (1.145.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (3.10.1)
# Requirement already satisfied: google-cloud-vectorsearch>=0.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (0.9.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (0.28.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (1.2.27)
# Requirement already satisfied: langchain-tests>=1.0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (1.1.5)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.6 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (2.14.1)
# Requirement already satisfied: pyarrow<23.0.0,>=19.0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (22.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (2.12.5)
# Requirement already satisfied: validators<1.0.0,>=0.22.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-google-vertexai) (0.35.0)
# Requirement already satisfied: numpy in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from bottleneck<2.0.0,>=1.4.0->langchain-google-vertexai) (2.4.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.30.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.49.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.27.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (24.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.41.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.17.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.59.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.70.0)
# Requirement already satisfied: typing_extensions in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (4.15.0)
# Requirement already satisfied: docstring_parser<1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.74.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.33.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.80.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (46.0.6)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.8.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-cloud-storage<4.0.0,>=2.18.0->langchain-google-vertexai) (1.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (4.13.0)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.59.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.11)
# Requirement already satisfied: certifi in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.0->langchain-google-vertexai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpx<1.0.0,>=0.28.0->langchain-google-vertexai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.0->langchain-google-vertexai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (0.7.26)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.7->langchain-google-vertexai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pydantic<3.0.0,>=2.9.0->langchain-google-vertexai) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (3.0)
# Requirement already satisfied: pytest-asyncio<2.0.0,>=0.20.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (1.3.0)
# Requirement already satisfied: pytest-benchmark in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (5.2.3)
# Requirement already satisfied: pytest-codspeed in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (4.3.0)
# Requirement already satisfied: pytest-recording in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (0.13.4)
# Requirement already satisfied: pytest-socket<1.0.0,>=0.7.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (0.7.0)
# Requirement already satisfied: pytest<10.0.0,>=7.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (9.0.3)
# Requirement already satisfied: syrupy<6.0.0,>=4.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (5.1.0)
# Requirement already satisfied: vcrpy<9.0.0,>=8.0.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from langchain-tests>=1.0.1->langchain-google-vertexai) (8.1.1)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pytest<10.0.0,>=7.0.0->langchain-tests>=1.0.1->langchain-google-vertexai) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pytest<10.0.0,>=7.0.0->langchain-tests>=1.0.1->langchain-google-vertexai) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pytest<10.0.0,>=7.0.0->langchain-tests>=1.0.1->langchain-google-vertexai) (2.20.0)
# Requirement already satisfied: wrapt in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from vcrpy<9.0.0,>=8.0.0->langchain-tests>=1.0.1->langchain-google-vertexai) (2.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-cloud-aiplatform<2.0.0,>=1.97.0->langchain-google-vertexai) (0.6.3)
# Requirement already satisfied: py-cpuinfo in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pytest-benchmark->langchain-tests>=1.0.1->langchain-google-vertexai) (9.0.0)
# Requirement already satisfied: rich>=13.8.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from pytest-codspeed->langchain-tests>=1.0.1->langchain-google-vertexai) (14.3.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from rich>=13.8.1->pytest-codspeed->langchain-tests>=1.0.1->langchain-google-vertexai) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/anideepkalia/Desktop/PolyQuery-AI/venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.1->pytest-codspeed->langchain-tests>=1.0.1->langchain-google-vertexai) (0.1.2)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# In terminal google cloud vertex ai setup
    # !curl https://sdk.cloud.google.com | bash
    # ! gcloud auth application-default login
# !curl "https://aiplatform.googleapis.com/v1/publishers/google/models/gemini-3-flash-preview:streamGenerateContent?key=" -X POST -H "Content-Type: application/json" -d '{"contents":[{"role":"user","parts":[{"text":"Explain how AI works in a few words"}]}]}'
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Declaration

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.documents import Document
from langchain_core.output_parsers import JsonOutputParser
import transformers
import json
import numpy as np
import os
import warnings
from dotenv import load_dotenv
from pydantic import BaseModel
from typing import List
from langchain_community.retrievers import BM25Retriever
from langgraph.graph import StateGraph, END
from pydantic import BaseModel
from typing import TypedDict, List
from sentence_transformers import CrossEncoder
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
import time
import vertexai
from langchain_google_vertexai import ChatVertexAI
from sklearn.metrics.pairwise import cosine_similarity



load_dotenv()
langchain_api_key = os.getenv("LANGCHAIN_API_KEY")
hf_token = os.getenv("HUGGINGFACEHUB_API_TOKEN")
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
warnings.filterwarnings("ignore")
FAITHFULNESS_PASS_SCORE = 0.85
ABSTENTION_FAITHFULNESS_THRESHOLD = FAITHFULNESS_PASS_SCORE
MAX_FAITHFULNESS_RETRIES = 2



warnings.filterwarnings("ignore")


class QueryOutput(BaseModel):
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str

class QueryOptimizerOutput(BaseModel):
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str

class GraphState(TypedDict):
    query: str
    rewritten_query: str
    expanded_queries: List[str]
    step_back_query: str
    documents: List[Document]
    answer: str
    claims: List[str]                 # NEW
    plan: dict                        # NEW
    iteration: int
    retrieval_feedback: dict
    doc_scores: List[float]
    faithfulness: dict                 # NEW
    faithfulness_score: float          # NEW
    confidence_label: str              # NEW
    unsupported_claims: List[str]      # NEW
    faithfulness_retry_count: int      # NEW
    faithfulness_feedback: dict        # NEW
    abstention: dict                   # NEW
    abstention_decision: str           # NEW
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Models

# %%
vertexai.init(project="pleet-d8210", location="global")
llm_compression = ChatVertexAI( model="gemini-3.1-pro-preview" )
llm = ChatVertexAI( model="gemini-3.1-pro-preview" )

structured_llm = llm.with_structured_output(QueryOutput)
cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
embeddings = HuggingFaceEmbeddings(model_name="nomic-ai/nomic-embed-text-v1",model_kwargs={"trust_remote_code": True})
# Out:
# Loading weights: 100%|██████████| 105/105 [00:00<00:00, 16886.58it/s]
# BertForSequenceClassification LOAD REPORT from: cross-encoder/ms-marco-MiniLM-L-6-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# <All keys matched successfully>
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import random

def safe_llm_invoke(llm, prompt, retries=5):
    last_error = None

    for i in range(retries):
        try:
            return llm.invoke(prompt)
        except Exception as e:
            last_error = e
            wait_time = (2 ** i) + random.uniform(0, 1)
            print(f"[Retry {i+1}] Waiting {wait_time:.2f}s →", repr(e))
            time.sleep(wait_time)

    raise last_error
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Query Rewritting & Expansion
#
# * User Query  ->  Query Rewriting  ->  Step-Back Query  ->  Query Expansion
#
#
# | Step      | Why                                      |
# | --------- | ---------------------------------------- |
# | Rewrite   | cleans the query and removes ambiguity   |
# | Step-back | captures **higher-level concept**        |
# | Expansion | generates **multiple search variations** |

# %%
optimizer_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert query optimizer. Return ONLY JSON."),
    ("human", """
        User Query:
        {query}

        Perform:
        1. Rewrite query
        2. Generate 3 variations
        3. Generate step-back query

        Return JSON:

        {{
        "rewritten_query": "...",
        "expanded_queries": ["...", "...", "...", "..."],
        "step_back_query": "..."
        }}
    """)
])

def query_intelligence_node(state):

    iteration = state.get("iteration", 0)

    if iteration == 0:
        query = state["query"]
        prompt = optimizer_prompt.invoke({"query": query})
    else:
        feedback = state.get("retrieval_feedback", {})
        snippets = [
            doc.page_content[:200]
            for doc in state.get("documents", [])[:2]
        ]

        refined_query = f"""
            Previous retrieval failed.

            Reason: {feedback.get("reason")}
            Max Score: {feedback.get("max_score")}
            Avg Score: {feedback.get("avg_score")}
            Missing Information: {feedback.get("missing_information")}
            Unsupported Sub-questions: {feedback.get("unsupported_sub_questions")}
            Coverage: {feedback.get("coverage")}

            The following snippets were retrieved but are NOT relevant:
            {chr(10).join(snippets)}

            IMPORTANT:
            - These snippets are incorrect or irrelevant
            - Do NOT base your query on them
            - Use them only to understand what went wrong

            Original Query:
            {state["query"]}

            Previous Rewritten Query:
            {state.get("rewritten_query")}

            Previous Expanded Query:
            {state.get("expanded_queries")}

            Previous Step_back Query:
            {state.get("step_back_query")}

            Your task:
            - Identify why retrieval failed
            - Fix the query without drifting away from user intent
            - Preserve original intent strictly
            - Improve specificity and keywords
        """
        prompt = optimizer_prompt.invoke({"query": refined_query})

    result = safe_llm_invoke(structured_llm, prompt)

    return {
        "rewritten_query": result.rewritten_query,
        "expanded_queries": result.expanded_queries,
        "step_back_query": result.step_back_query
    }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## VECTOR-DB, EMBEDDINGS & INGESTION

# %%
def load_documents_from_txt(file_path):
    documents = []
    
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    
    for line in lines:
        line = line.strip()
        if line:  # skip empty lines
            documents.append(Document(page_content=line))
    
    return documents

file_path = "data.txt"
documents = load_documents_from_txt(file_path)


vectorstore = Chroma.from_documents(
    documents=documents,
    collection_name="verirag-chroma",
    embedding=embeddings,
)

vector_retriever = vectorstore.as_retriever(search_kwargs={"k": 5})
bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 5
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## RETRIEVER

# %%
# Retrieve top 5 results from both BM25 and Vector retrievers, then deduplicate results
def hybrid_retrieve_node(state):
    queries = (
        [state["rewritten_query"]] +
        state["expanded_queries"] +
        [state["step_back_query"]]
    )

    all_docs = []
    print("----------------------------")
    for q in queries:
        print("Query: ",q)
        all_docs.extend(bm25_retriever.invoke(q))
        all_docs.extend(vector_retriever.invoke(q))
        print(all_docs)
        
    print("----------------------------")
    # Deduplicate
    unique_docs = list({doc.page_content: doc for doc in all_docs}.values())

    return {"documents": unique_docs}
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Cross Encoder & Re-Ranking

# %%
# Rerank retrieved documents using cross-encoder, normalised scores and filter out low-relevance docs based on a threshold
def rerank_and_filter_node(state):

    docs = state.get("documents", [])
    query = state["query"]

    if not docs:
        return {
            "documents": [],
            "answer": "I don't know",
            "retrieval_feedback": {"reason": "no_docs"}
        }

    pairs = [(query, doc.page_content) for doc in docs]
    scores = cross_encoder.predict(pairs)
    scores = 1 / (1 + np.exp(-scores))

    doc_scores = list(zip(docs, scores))
    doc_scores.sort(key=lambda x: x[1], reverse=True)

    top_docs = doc_scores[:5]
    top_scores = [score for _, score in top_docs]
    max_score = max(top_scores)
    avg_score = sum(top_scores) / len(top_scores)
    print(top_scores, max_score, avg_score)
    print("----------------------------")

    print("rerank: ",[doc for doc, _ in top_docs])
    print("--------------------------------------")

    upper_threshold = 0.7
    lower_threshold = 0.4
    

    if max_score < lower_threshold:
        print("below lower threshold")
        return {
            "documents": [doc for doc, _ in top_docs],
            "answer": "I don't know"
        }

    elif max_score < upper_threshold:
        print("below upper threshold")
        return {
            "documents": [doc for doc, _ in top_docs],
            "doc_scores": top_scores,
            "retrieval_feedback": {
                "reason": "low_relevance",
                "max_score": float(max_score),
                "avg_score": float(avg_score)
            }
        }
    else:
        print("above upper threshold")
        return {
            "documents": [doc for doc, _ in top_docs],
            "doc_scores": top_scores
        }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def Retry_decision_logic(state):

    iteration = state.get("iteration", 0)
    max_iterations = 2

    if state.get("retrieval_feedback") != None and iteration < max_iterations:
        return "retry"

    # If no docs → retry
    if not state.get("documents") and iteration < max_iterations:
        return "retry"

    return "generate"

def Refine_query_node(state):
    return {
        "iteration": state.get("iteration", 0) + 1
    }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Compression Node

# %%
def extract_text(response):
    content = response.content

    if isinstance(content, list):
        return " ".join([item.get("text", "") for item in content]).strip()
    
    return content.strip()


def compress_documents_node(state):

    query = state["query"]
    docs = state.get("documents", [])[:3]

    if not docs:
        return {"documents": []}

    # Embed query once
    query_embedding = embeddings.embed_query(query)

    compressed_docs = []

    total_original_tokens = 0
    total_compressed_tokens = 0

    for doc in docs:

        text = doc.page_content

        # Rough token count (interview acceptable approximation)
        total_original_tokens += len(text.split())

        # Step 1: sentence splitting (simple but effective)
        sentences = [s.strip() for s in text.split(".") if len(s.strip()) > 10]

        if not sentences:
            compressed_docs.append(doc)
            continue

        # Step 2: embed sentences
        sentence_embeddings = embeddings.embed_documents(sentences)

        # Step 3: similarity scoring
        scores = cosine_similarity(
            [query_embedding],
            sentence_embeddings
        )[0]

        # Step 4: pick top-k sentences
        top_k = min(3, len(sentences))

        top_indices = np.argsort(scores)[-top_k:]
        top_indices = sorted(top_indices)  # preserve order

        selected_sentences = [sentences[i] for i in top_indices]

        compressed_text = ". ".join(selected_sentences)

        total_compressed_tokens += len(compressed_text.split())

        compressed_docs.append(Document(page_content=compressed_text))

    # 🔥 LOGGING (THIS is what impresses interviewers)
    print("📉 Compression Stats:")
    print(f"Original tokens: {total_original_tokens}")
    print(f"Compressed tokens: {total_compressed_tokens}")

    if total_original_tokens > 0:
        reduction = 1 - (total_compressed_tokens / total_original_tokens)
        print(f"Reduction: {reduction:.2%}")
    
    return {"documents": compressed_docs}
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Answer Planning Node

# %%
def build_empty_plan():
    return {
        "sub_questions": [],
        "required_info": [],
        "evidence_mapping": [],
        "expected_claims": [],
        "supported_claims": [],
        "missing_information": [],
        "risk_flags": ["insufficient_evidence"],
        "answer_mode": "abstain",
        "ordered_evidence": [],
        "coverage": {
            "supported_sub_questions": 0,
            "total_sub_questions": 0,
            "sub_question_coverage": 0.0,
            "supported_claims": 0,
            "total_expected_claims": 0,
            "claim_support_ratio": 0.0
        }
    }


def parse_json_response(response, fallback):
    raw = extract_text(response)

    try:
        return json.loads(raw)
    except Exception:
        start = raw.find("{")
        end = raw.rfind("}")

        if start != -1 and end != -1 and end > start:
            try:
                return json.loads(raw[start:end + 1])
            except Exception:
                pass

    return fallback


def normalize_list(value):
    if isinstance(value, list):
        return [str(item).strip() for item in value if str(item).strip()]

    if isinstance(value, str) and value.strip():
        return [value.strip()]

    return []


def build_sentence_pool(docs):
    sentence_pool = []

    for doc_id, doc in enumerate(docs, start=1):
        sentences = [
            sentence.strip()
            for sentence in doc.page_content.replace("\n", " ").split(".")
            if len(sentence.strip()) > 10
        ]

        for sentence in sentences:
            sentence_pool.append({
                "doc_id": f"DOC_{doc_id}",
                "text": sentence
            })

    return sentence_pool


def rank_sentence_pool(query, sentence_pool, sentence_embeddings, top_k=2):
    if not sentence_pool or len(sentence_embeddings) == 0:
        return []

    query_embedding = embeddings.embed_query(query)
    scores = cosine_similarity([query_embedding], sentence_embeddings)[0]
    ranked_indices = np.argsort(scores)[::-1]

    ranked = []
    for idx in ranked_indices[:top_k]:
        ranked.append({
            "doc_id": sentence_pool[idx]["doc_id"],
            "text": sentence_pool[idx]["text"],
            "score": round(float(scores[idx]), 4)
        })

    return ranked


def answer_planning_node(state):
    query = state["query"]
    docs = state.get("documents", [])
    empty_plan = build_empty_plan()
    previous_answer = str(state.get("answer", "") or "").strip()
    previous_claims = normalize_list(state.get("claims", []))
    previous_faithfulness = state.get("faithfulness", {}) or {}

    try:
        previous_faithfulness_score = float(
            state.get("faithfulness_score", previous_faithfulness.get("faithfulness_score", 0.0)) or 0.0
        )
    except Exception:
        previous_faithfulness_score = 0.0

    try:
        faithfulness_retry_count = int(state.get("faithfulness_retry_count", 0) or 0)
    except Exception:
        faithfulness_retry_count = 0

    is_faithfulness_retry = (
        previous_answer
        and previous_answer != "I don't know"
        and previous_faithfulness_score < FAITHFULNESS_PASS_SCORE
        and faithfulness_retry_count < MAX_FAITHFULNESS_RETRIES
    )

    retry_updates = {}
    if is_faithfulness_retry:
        retry_updates = {
            "faithfulness_retry_count": faithfulness_retry_count + 1,
            "faithfulness_feedback": {
                "previous_answer": previous_answer,
                "previous_claims": previous_claims,
                "judge_analysis": previous_faithfulness,
                "faithfulness_score": previous_faithfulness_score,
                "retry_number": faithfulness_retry_count + 1
            }
        }

    if not docs:
        return {
            "plan": empty_plan,
            "retrieval_feedback": {
                "reason": "planner_found_no_documents",
                "missing_information": ["No retrieved evidence available for answer planning."],
                "unsupported_sub_questions": [query]
            },
            **retry_updates
        }

    context_blocks = [
        f"[DOC_{idx}] {doc.page_content}"
        for idx, doc in enumerate(docs, start=1)
    ]
    context = "\n\n".join(context_blocks)
    retry_guidance = ""

    if is_faithfulness_retry:
        retry_guidance = f"""
Previous generation failed the Faithfulness Judge.
Faithfulness retry: {faithfulness_retry_count + 1}/{MAX_FAITHFULNESS_RETRIES}

Previous answer:
{previous_answer}

Previous claims:
{json.dumps(previous_claims, indent=2)}

Judge analysis:
{json.dumps(previous_faithfulness, indent=2)}

When creating the new plan:
- Do not repeat unsupported, weakly supported, or contradicted claims.
- Keep expected_claims only to facts directly backed by the context.
- Prefer evidence sentences that directly support each claim.
"""
        print(f"🔁 Faithfulness retry {faithfulness_retry_count + 1}/{MAX_FAITHFULNESS_RETRIES}: replanning with judge feedback")

    prompt = f"""
You are an answer planning engine for a RAG system.

Your job is to create a plan that can be executed before final generation.

Given:
Question: {query}

Context:
{context}

{retry_guidance}

Instructions:
1. Break the question into 2 to 4 answerable sub-questions
2. List the key information required
3. List atomic factual claims that a good answer would make
4. If the context is missing key evidence or looks conflicting, set answer_mode to "abstain"
5. Use ONLY the given context

Return STRICT JSON:

{{
  "sub_questions": ["...", "..."],
  "required_info": ["...", "..."],
  "expected_claims": ["...", "..."],
  "missing_information": ["..."],
  "risk_flags": ["insufficient_evidence"],
  "answer_mode": "grounded_answer"
}}
"""
    response = safe_llm_invoke(llm, prompt)
    plan = parse_json_response(response, build_empty_plan())

    plan["sub_questions"] = normalize_list(plan.get("sub_questions"))
    plan["required_info"] = normalize_list(plan.get("required_info"))
    plan["expected_claims"] = normalize_list(plan.get("expected_claims"))
    plan["missing_information"] = normalize_list(plan.get("missing_information"))
    plan["risk_flags"] = normalize_list(plan.get("risk_flags"))

    if len(plan["sub_questions"]) < 2:
        plan["sub_questions"] = [
            f"What is the direct answer to: {query}?",
            "Which retrieved facts support that answer?"
        ]

    if not plan["required_info"]:
        plan["required_info"] = [f"Evidence needed to answer: {query}"]

    plan["answer_mode"] = "abstain" if plan.get("answer_mode") == "abstain" else "grounded_answer"

    sentence_pool = build_sentence_pool(docs)
    sentence_texts = [item["text"] for item in sentence_pool]
    sentence_embeddings = embeddings.embed_documents(sentence_texts) if sentence_texts else []

    min_support_score = 0.3
    evidence_mapping = []
    ordered_evidence = []
    supported_sub_questions = []

    for sub_question in plan["sub_questions"]:
        ranked = rank_sentence_pool(sub_question, sentence_pool, sentence_embeddings, top_k=2)
        supporting = [item for item in ranked if item["score"] >= min_support_score]

        if supporting:
            supported_sub_questions.append(sub_question)

        evidence_mapping.append({
            "sub_question": sub_question,
            "supporting_sentences": [item["text"] for item in supporting],
            "source_docs": [item["doc_id"] for item in supporting],
            "support_score": supporting[0]["score"] if supporting else 0.0
        })

        for item in supporting:
            if item["text"] not in ordered_evidence:
                ordered_evidence.append(item["text"])

    supported_claims = []
    for claim in plan["expected_claims"]:
        ranked = rank_sentence_pool(claim, sentence_pool, sentence_embeddings, top_k=1)

        if ranked and ranked[0]["score"] >= min_support_score:
            supported_claims.append(claim)

            if ranked[0]["text"] not in ordered_evidence:
                ordered_evidence.append(ranked[0]["text"])

    if not supported_claims and ordered_evidence:
        supported_claims = ordered_evidence[:min(3, len(ordered_evidence))]

    sub_question_coverage = round(
        len(supported_sub_questions) / max(1, len(plan["sub_questions"])),
        2
    )
    claim_support_ratio = round(
        len(supported_claims) / max(1, len(plan["expected_claims"])),
        2
    ) if plan["expected_claims"] else round(float(bool(supported_claims)), 2)

    plan["evidence_mapping"] = evidence_mapping
    plan["supported_claims"] = supported_claims
    plan["ordered_evidence"] = ordered_evidence
    plan["coverage"] = {
        "supported_sub_questions": len(supported_sub_questions),
        "total_sub_questions": len(plan["sub_questions"]),
        "sub_question_coverage": sub_question_coverage,
        "supported_claims": len(supported_claims),
        "total_expected_claims": len(plan["expected_claims"]),
        "claim_support_ratio": claim_support_ratio
    }

    risk_flags = set(plan["risk_flags"])

    if sub_question_coverage < 1.0 or not ordered_evidence:
        risk_flags.add("insufficient_evidence")

    if plan["expected_claims"] and claim_support_ratio < 1.0:
        risk_flags.add("unsupported_claims")

    plan["risk_flags"] = sorted(risk_flags)

    if (
        "conflicting_evidence" in plan["risk_flags"]
        or plan["answer_mode"] == "abstain"
        or sub_question_coverage < 0.5
        or not supported_claims
        or not ordered_evidence
    ):
        plan["answer_mode"] = "abstain"
    else:
        plan["answer_mode"] = "grounded_answer"

    print("🧠 Answer Plan Summary:", {
        "answer_mode": plan["answer_mode"],
        "coverage": plan["coverage"],
        "risk_flags": plan["risk_flags"],
        "supported_claims": plan["supported_claims"]
    })

    if plan["answer_mode"] == "abstain" and "insufficient_evidence" in plan["risk_flags"]:
        unsupported = [
            item["sub_question"]
            for item in evidence_mapping
            if not item["supporting_sentences"]
        ]

        return {
            "plan": plan,
            "retrieval_feedback": {
                "reason": "planner_detected_missing_evidence",
                "missing_information": plan["missing_information"],
                "unsupported_sub_questions": unsupported or plan["sub_questions"],
                "coverage": plan["coverage"]
            },
            **retry_updates
        }

    return {"plan": plan, **retry_updates}


def planning_decision_logic(state):
    iteration = state.get("iteration", 0)
    max_iterations = 2
    plan = state.get("plan", {})
    risk_flags = plan.get("risk_flags", [])

    if (
        plan.get("answer_mode") == "abstain"
        and "insufficient_evidence" in risk_flags
        and iteration < max_iterations
    ):
        return "retry"

    return "generate"
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## GENERATION

# %%
def generate_answer_node(state):

    if state.get("answer") == "I don't know":
        return {"answer": "I don't know", "claims": []}

    docs = state.get("documents", [])
    plan = state.get("plan", build_empty_plan())

    if not docs:
        return {"answer": "I don't know", "claims": []}

    if not plan or plan.get("answer_mode") != "grounded_answer":
        print("Generator abstained due to plan:", plan.get("risk_flags", []))
        return {"answer": "I don't know", "claims": []}

    ordered_evidence = plan.get("ordered_evidence", [])
    supported_claims = plan.get("supported_claims", [])

    if not ordered_evidence or not supported_claims:
        return {"answer": "I don't know", "claims": []}

    prompt = f"""
You are a strict grounded answer generator.

Question:
{state["query"]}

Sub-questions:
{json.dumps(plan.get("sub_questions", []), indent=2)}

Evidence mapping:
{json.dumps(plan.get("evidence_mapping", []), indent=2)}

Allowed evidence sentences:
{json.dumps(ordered_evidence, indent=2)}

Supported claims you MAY use:
{json.dumps(supported_claims, indent=2)}

Instructions:
- Use ONLY the allowed evidence sentences
- Answer the question directly and concisely
- Keep claims atomic and factual
- Claims must stay within the supported_claims list
- If the evidence is not enough, return \"I don't know\"

Return STRICT JSON:

{{
  "answer": "...",
  "claims": ["...", "..."]
}}
"""

    response = safe_llm_invoke(llm, prompt)
    result = parse_json_response(response, {"answer": "I don't know", "claims": []})

    result["claims"] = normalize_list(result.get("claims"))
    allowed_claims = set(supported_claims)
    filtered_claims = [claim for claim in result["claims"] if claim in allowed_claims]

    if not filtered_claims:
        filtered_claims = supported_claims

    if not filtered_claims:
        return {"answer": "I don't know", "claims": []}

    return {
        "answer": " ".join(filtered_claims),
        "claims": filtered_claims
    }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Faithfulness Judge Node

# %%
def build_empty_faithfulness_result(reason="not_evaluated"):
    return {
        "faithfulness_score": 0.0,
        "evidence_coverage_score": 0.0,
        "retrieval_confidence": 0.0,
        "final_confidence": 0.0,
        "confidence_label": "low",
        "claim_judgments": [],
        "unsupported_claims": [],
        "weakly_supported_claims": [],
        "contradicted_claims": [],
        "reason": reason
    }


def clamp_score(value):
    try:
        return max(0.0, min(1.0, float(value)))
    except Exception:
        return 0.0


def normalize_claim_status(status):
    status = str(status).strip().lower().replace(" ", "_").replace("-", "_")

    if status in {"supported", "fully_supported", "entailed"}:
        return "supported"

    if status in {"partial", "partially_supported", "weakly_supported", "mixed"}:
        return "partially_supported"

    if status in {"contradicted", "contradiction", "conflicting"}:
        return "contradicted"

    return "unsupported"


def confidence_label_from_score(score):
    score = clamp_score(score)

    if score >= 0.85:
        return "high"

    if score >= 0.60:
        return "medium"

    return "low"


def get_evidence_sentences(state):
    plan = state.get("plan", {}) or {}
    ordered_evidence = normalize_list(plan.get("ordered_evidence", []))

    if ordered_evidence:
        return ordered_evidence

    docs = state.get("documents", [])
    sentences = []

    for doc in docs:
        for sentence in doc.page_content.replace("\n", " ").split("."):
            sentence = sentence.strip()

            if len(sentence) > 10:
                sentences.append(sentence)

    return sentences


def calculate_retrieval_confidence(state):
    doc_scores = state.get("doc_scores", []) or []

    if not doc_scores:
        return 0.0

    return round(sum(clamp_score(score) for score in doc_scores) / len(doc_scores), 4)


def fallback_claim_judgments(claims, evidence_sentences):
    if not claims:
        return []

    if not evidence_sentences:
        return [
            {
                "claim": claim,
                "status": "unsupported",
                "supporting_doc_ids": [],
                "support_score": 0.0,
                "reason": "No evidence sentences were available."
            }
            for claim in claims
        ]

    evidence_embeddings = embeddings.embed_documents(evidence_sentences)
    judgments = []

    for claim in claims:
        claim_embedding = embeddings.embed_query(claim)
        scores = cosine_similarity([claim_embedding], evidence_embeddings)[0]
        best_idx = int(np.argmax(scores))
        best_score = clamp_score(scores[best_idx])

        if best_score >= 0.75:
            status = "supported"
        elif best_score >= 0.55:
            status = "partially_supported"
        else:
            status = "unsupported"

        judgments.append({
            "claim": claim,
            "status": status,
            "supporting_doc_ids": [f"EVIDENCE_{best_idx + 1}"],
            "support_score": round(best_score, 4),
            "reason": f"Fallback embedding similarity matched evidence sentence {best_idx + 1}."
        })

    return judgments


def score_claim_judgments(claim_judgments):
    score_map = {
        "supported": 1.0,
        "partially_supported": 0.5,
        "unsupported": 0.0,
        "contradicted": 0.0
    }

    normalized = []

    for item in claim_judgments:
        claim = str(item.get("claim", "")).strip()

        if not claim:
            continue

        status = normalize_claim_status(item.get("status", "unsupported"))
        normalized.append({
            "claim": claim,
            "status": status,
            "supporting_doc_ids": normalize_list(item.get("supporting_doc_ids", [])),
            "support_score": clamp_score(item.get("support_score", score_map[status])),
            "reason": str(item.get("reason", "")).strip()
        })

    if not normalized:
        return normalized, 0.0

    score = sum(score_map[item["status"]] for item in normalized) / len(normalized)
    return normalized, round(score, 4)


def faithfulness_judge_node(state):
    answer = str(state.get("answer", "")).strip()
    claims = normalize_list(state.get("claims", []))

    if not answer or answer == "I don't know":
        result = build_empty_faithfulness_result("answer_abstained_or_empty")
        result["confidence_label"] = "abstained"
        return {
            "faithfulness": result,
            "faithfulness_score": result["faithfulness_score"],
            "confidence_label": result["confidence_label"],
            "unsupported_claims": result["unsupported_claims"]
        }

    if not claims:
        claims = [answer]

    evidence_sentences = get_evidence_sentences(state)
    evidence_context = "\n".join(
        f"[EVIDENCE_{idx}] {sentence}"
        for idx, sentence in enumerate(evidence_sentences, start=1)
    )

    prompt = f"""
You are a strict faithfulness evaluator for a RAG system.

Question:
{state["query"]}

Answer:
{answer}

Atomic answer claims:
{json.dumps(claims, indent=2)}

Evidence:
{evidence_context}

Instructions:
- Use ONLY the evidence above.
- Judge whether each claim is supported by the evidence.
- Do not use outside knowledge.
- Mark a claim as "supported" only when the evidence directly supports it.
- Mark a claim as "partially_supported" when evidence is related but incomplete.
- Mark a claim as "unsupported" when evidence does not prove it.
- Mark a claim as "contradicted" when evidence conflicts with it.

Return STRICT JSON:
{{
  "claim_judgments": [
    {{
      "claim": "...",
      "status": "supported | partially_supported | unsupported | contradicted",
      "supporting_doc_ids": ["EVIDENCE_1"],
      "reason": "short reason"
    }}
  ]
}}
"""

    fallback = {"claim_judgments": fallback_claim_judgments(claims, evidence_sentences)}
    response = safe_llm_invoke(llm, prompt)
    judged = parse_json_response(response, fallback)
    claim_judgments = judged.get("claim_judgments") or fallback["claim_judgments"]
    claim_judgments, faithfulness_score = score_claim_judgments(claim_judgments)

    plan = state.get("plan", {}) or {}
    coverage = plan.get("coverage", {}) or {}
    evidence_coverage_score = clamp_score(coverage.get("claim_support_ratio", faithfulness_score))
    retrieval_confidence = calculate_retrieval_confidence(state)
    final_confidence = round(
        (0.55 * faithfulness_score)
        + (0.30 * evidence_coverage_score)
        + (0.15 * retrieval_confidence),
        4
    )

    unsupported_claims = [
        item["claim"]
        for item in claim_judgments
        if item["status"] == "unsupported"
    ]
    weakly_supported_claims = [
        item["claim"]
        for item in claim_judgments
        if item["status"] == "partially_supported"
    ]
    contradicted_claims = [
        item["claim"]
        for item in claim_judgments
        if item["status"] == "contradicted"
    ]

    confidence_label = confidence_label_from_score(final_confidence)

    if contradicted_claims:
        confidence_label = "low"

    result = {
        "faithfulness_score": faithfulness_score,
        "evidence_coverage_score": round(evidence_coverage_score, 4),
        "retrieval_confidence": retrieval_confidence,
        "final_confidence": final_confidence,
        "confidence_label": confidence_label,
        "claim_judgments": claim_judgments,
        "unsupported_claims": unsupported_claims,
        "weakly_supported_claims": weakly_supported_claims,
        "contradicted_claims": contradicted_claims,
        "reason": "Confidence combines claim faithfulness, planner evidence coverage, and retrieval scores."
    }

    print("✅ Faithfulness Judge:", {
        "faithfulness_score": result["faithfulness_score"],
        "final_confidence": result["final_confidence"],
        "confidence_label": result["confidence_label"],
        "unsupported_claims": result["unsupported_claims"],
        "weakly_supported_claims": result["weakly_supported_claims"],
        "contradicted_claims": result["contradicted_claims"]
    })

    return {
        "faithfulness": result,
        "faithfulness_score": result["faithfulness_score"],
        "confidence_label": result["confidence_label"],
        "unsupported_claims": result["unsupported_claims"]
    }


def abstention_threshold_node(state):
    answer = str(state.get("answer", "") or "").strip()
    faithfulness = state.get("faithfulness", {}) or {}
    faithfulness_score = clamp_score(
        faithfulness.get("faithfulness_score", state.get("faithfulness_score", 0.0))
    )
    final_confidence = clamp_score(faithfulness.get("final_confidence", 0.0))
    retry_count = int(state.get("faithfulness_retry_count", 0) or 0)
    unsupported_claims = normalize_list(faithfulness.get("unsupported_claims", state.get("unsupported_claims", [])))
    weakly_supported_claims = normalize_list(faithfulness.get("weakly_supported_claims", []))
    contradicted_claims = normalize_list(faithfulness.get("contradicted_claims", []))

    abstention = {
        "threshold": ABSTENTION_FAITHFULNESS_THRESHOLD,
        "faithfulness_score": faithfulness_score,
        "final_confidence": final_confidence,
        "retry_count": retry_count,
        "max_retries": MAX_FAITHFULNESS_RETRIES,
        "unsupported_claims": unsupported_claims,
        "weakly_supported_claims": weakly_supported_claims,
        "contradicted_claims": contradicted_claims,
        "rejected_answer": ""
    }

    if not answer or answer == "I don't know":
        abstention.update({
            "decision": "abstain",
            "reason": "answer_abstained_or_empty"
        })
        return {
            "answer": "I don't know",
            "claims": [],
            "abstention": abstention,
            "abstention_decision": "abstain"
        }

    has_hard_failure = bool(unsupported_claims or contradicted_claims)
    passes_threshold = faithfulness_score >= ABSTENTION_FAITHFULNESS_THRESHOLD and not has_hard_failure

    if passes_threshold:
        abstention.update({
            "decision": "accept",
            "reason": "faithfulness_passed_threshold"
        })
        print("🟢 Abstention Threshold:", abstention)
        return {
            "abstention": abstention,
            "abstention_decision": "accept"
        }

    if retry_count < MAX_FAITHFULNESS_RETRIES:
        abstention.update({
            "decision": "retry",
            "reason": "faithfulness_below_threshold_or_has_unsupported_claims"
        })
        print(
            f"🟡 Abstention Threshold: retry {retry_count + 1}/{MAX_FAITHFULNESS_RETRIES} "
            f"because score={faithfulness_score:.2f}, threshold={ABSTENTION_FAITHFULNESS_THRESHOLD:.2f}, "
            f"unsupported={len(unsupported_claims)}, contradicted={len(contradicted_claims)}"
        )
        return {
            "abstention": abstention,
            "abstention_decision": "retry"
        }

    abstention.update({
        "decision": "abstain",
        "reason": "faithfulness_failed_after_max_retries",
        "rejected_answer": answer
    })
    print("🔴 Abstention Threshold: abstaining after max retries", abstention)
    return {
        "answer": "I don't know",
        "claims": [],
        "abstention": abstention,
        "abstention_decision": "abstain"
    }


def abstention_decision_logic(state):
    return state.get("abstention_decision", "abstain")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Graph Compliation

# %%
builder = StateGraph(GraphState)

builder.add_node("query_intelligence", query_intelligence_node)
builder.add_node("hybrid_retrieve", hybrid_retrieve_node)
builder.add_node("rerank", rerank_and_filter_node)
builder.add_node("Refine_query", Refine_query_node)
builder.add_node("Claim aware generation", generate_answer_node)
builder.add_node("Faithfulness Judge", faithfulness_judge_node)
builder.add_node("Abstention Threshold", abstention_threshold_node)
builder.add_node("Plan", answer_planning_node)
builder.add_node("Compress", compress_documents_node)

builder.set_entry_point("query_intelligence")

builder.add_edge("query_intelligence", "hybrid_retrieve")
builder.add_edge("hybrid_retrieve", "rerank")
builder.add_edge("Compress", "Plan")

builder.add_conditional_edges(
    "rerank",
    Retry_decision_logic,
    {
        "retry": "Refine_query",
        "generate": "Compress"
    }
)

builder.add_conditional_edges(
    "Plan",
    planning_decision_logic,
    {
        "retry": "Refine_query",
        "generate": "Claim aware generation"
    }
)

builder.add_edge("Refine_query", "query_intelligence")
builder.add_edge("Claim aware generation", "Faithfulness Judge")
builder.add_edge("Faithfulness Judge", "Abstention Threshold")

builder.add_conditional_edges(
    "Abstention Threshold",
    abstention_decision_logic,
    {
        "retry": "Plan",
        "accept": END,
        "abstain": END
    }
)

graph = builder.compile()

from IPython.display import Image, display # type: ignore
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Inferencing RAG

# %%
result = graph.invoke({
    # "query": "How do we measure faithfulness in computer terminal?",
    "query": "How does RAG ensure grounded generation despite irrelevant retrieved documents?",
    # "query": "How do we measure faithfulness in RAG LLM?",
    # "query": "how tall is the Eiffel Tower ?",
    # "query": "What is a RAG system?",
    # "query": "What is my favorite color?",
    # "query": "What is my name??",
    "iteration": 0,
    "faithfulness_retry_count": 0
})

raw = result.get("answer", "")

if isinstance(raw, list) and len(raw) > 0:
    print(raw[0].get("text", ""))
else:
    print(raw)

print("Claims:", result.get("claims", []))
print("Planner Mode:", result.get("plan", {}).get("answer_mode"))
print("Planner Coverage:", result.get("plan", {}).get("coverage"))
print("Faithfulness Score:", result.get("faithfulness_score"))
print("Confidence Label:", result.get("confidence_label"))
print("Faithfulness Retries:", result.get("faithfulness_retry_count", 0))
print("Abstention Decision:", result.get("abstention_decision"))
print("Abstention Details:", result.get("abstention", {}))
print("Faithfulness Details:", result.get("faithfulness", {}))
# Out:
# ----------------------------
# Query:  How do Retrieval-Augmented Generation (RAG) systems maintain groundedness when provided with irrelevant retrieved context?
# [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.')]
# Query:  Techniques to prevent LLM hallucination in RAG pipelines with noisy or irrelevant retrieval results
# [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Query expansion generates multiple variations of a query. It improves recall in retrieval systems.'), Document(metadata={}, page_content='Retrieval latency affects system performance. Faster retrieval improves user experience.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.')]
# Query:  How do large language models in RAG systems ignore irrelevant context to generate accurate answers?
# [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Query expansion generates multiple variations of a query. It improves recall in retrieval systems.'), Document(metadata={}, page_content='Retrieval latency affects system performance. Faster retrieval improves user experience.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more  ...
# Query:  Improving robustness and grounded generation against irrelevant documents in Retrieval-Augmented Generation
# [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Query expansion generates multiple variations of a query. It improves recall in retrieval systems.'), Document(metadata={}, page_content='Retrieval latency affects system performance. Faster retrieval improves user experience.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more  ...
# Query:  What techniques are used to ensure groundedness and factuality in large language model generation?
# [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Query expansion generates multiple variations of a query. It improves recall in retrieval systems.'), Document(metadata={}, page_content='Retrieval latency affects system performance. Faster retrieval improves user experience.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Large language models can hallucinate. Grounding reduces hallucination risk.'), Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more  ...
# ----------------------------
# [np.float32(0.99617046), np.float32(0.025980486), np.float32(0.013442033), np.float32(0.0023377035), np.float32(0.00017849785)] 0.99617046 0.20762184
# ----------------------------
# rerank:  [Document(metadata={}, page_content='RAG systems combine retrieval and generation. Retrieval helps find relevant documents. Generation produces answers based on retrieved context. Irrelevant documents can reduce answer quality.'), Document(metadata={}, page_content='Some retrieved documents may be irrelevant. Filtering improves answer quality.'), Document(metadata={}, page_content='Faithfulness measures whether generated answers are supported by retrieved documents. High faithfulness means answers are grounded in evidence.'), Document(metadata={}, page_content='Incorrect context leads to incorrect answers. Correct retrieval is critical for RAG systems.'), Document(metadata={}, page_content='Cross-encoders rerank retrieved documents. They are slower but more accurate than bi-encoders.')]
# --------------------------------------
# above upper threshold
# 📉 Compression Stats:
# Original tokens: 52
# Compressed tokens: 46
# Reduction: 11.54%
